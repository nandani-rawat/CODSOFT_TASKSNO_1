# %%
# import Libraries

import pandas as pd
import numpy as np

# %%
# import data

df = pd.read_csv(
    r"C:\Users\vr380\OneDrive\Documents\panda_tutorial\Sample - Superstore.csv",
    encoding="latin1"
)

# %%
# Inspecting first 5 rows

print("First 5 rows are :")
df.head()
# Out:
# First 5 rows are :
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#inspecting last 5 rows
print("Last five rows are:")
df.tail()
# Out:
# Last five rows are:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
# ...

# %%
# Defining shape (columns x rows)
print("Shape of dataset is :")
df.shape
# Out:
# Shape of dataset is :
# (9994, 21)

# %%
# Finding information about the dataset

print("Information of dataset :")
df.info()
# Out:
# Information of dataset :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# datatypes

print("Different datatypes according to the columns :")
df.dtypes
# Out:
# Different datatypes according to the columns :
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
#dropping fully blank row

df = df.dropna(how ="all")
print("After dropping blank row" , df.shape)
# Out:
# After dropping blank row (9994, 21)

# %%
# Checking and handling missing values

print("Number of null values:")
df.isnull().sum()
# Out:
# Number of null values:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# changing row_id to index

df.set_index("Row ID", inplace =True)

# %%
# Rechecking Dataframe

print("Dataframe is :")
df
# Out:
# Dataframe is :
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 4       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9990    CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9991    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9994    CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
# ...

# %%
# finding duplicate value

print("number of duplicate values :")
dup_value = df.duplicated().sum()
dup_value
# Out:
# number of duplicate values :
# np.int64(1)

# %%
# Dropping duplicates

print("After removing duplicates :")
drop_dup= df.drop_duplicates()
drop_dup
# Out:
# After removing duplicates :
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 4       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...                ...         ...         ...             ...         ...
# 9990    CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9991    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993    CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9994    CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
# ...

# %%
# Rechecking shape if the diplicates are removed 
print("Shape changes from (9994,21) to :")
drop_dup.shape
# Out:
# Shape changes from (9994,21) to :
# (9993, 20)

# %%
# changing to date column

df["Order Date"]=pd.to_datetime(df["Order Date"])
df["Ship Date"]=pd.to_datetime(df["Ship Date"])

# %%
# changing date column with years only

df["Order Date"]=df["Order Date"].dt.year
df["Ship Date"]=df["Ship Date"].dt.year

# %%
print("Dataframe after cleaning the data :")
df.head()
# Out:
# Dataframe after cleaning the data :
#               Order ID  Order Date  Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156        2016       2016    Second Class    CG-12520
# 2       CA-2016-152156        2016       2016    Second Class    CG-12520
# 3       CA-2016-138688        2016       2016    Second Class    DV-13045
# 4       US-2015-108966        2015       2015  Standard Class    SO-20335
# 5       US-2015-108966        2015       2015  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
# Saving cleaned dataset

import os

path = r'C:\Users\vr380\OneDrive\Documents\panda_tutorial\Sample - Superstore.csv'

df.to_csv(path, index=False)
print("Saved at:", path)
# Out:
# Saved at: C:\Users\vr380\OneDrive\Documents\panda_tutorial\Sample - Superstore.csv
